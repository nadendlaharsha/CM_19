# %% [markdown]
# # 🚀 YouTube Summarizer Deployment
# **Instructions:**
# 1. Zip your entire local project folder `prj` (Exclude the `venv` folder).
# 2. Upload that zip file to Colab (Click the 'Folder' icon on the left, then the 'Upload' icon).
# 3. Run the cells below sequentially.

# %%
# 1. Unzip your uploaded project folder (Assumes you named it prj.zip)
# !unzip -q prj.zip -d prj
# %cd prj

# %%
# 2. Install Dependencies
# !pip install -q streamlit
# !pip install -q -r requirements_enhanced.txt
# !npm install -q localtunnel

# %%
# 3. Set API Key and Download NLTK Data
import os
import nltk

# 🔴 IMPORTANT: Replace with your actual Gemini API Key
os.environ['GOOGLE_API_KEY'] = 'YOUR_GEMINI_API_KEY_HERE'

nltk.download('punkt')
nltk.download('stopwords')
# !python fix_nltk.py

# %%
# 4. Get the Endpoint IP for LocalTunnel
import urllib.request
print("COPY THIS IP ADDRESS. Paste it as the 'Endpoint IP/Password' when you click the loca.lt link:")
print(urllib.request.urlopen('https://ipv4.icanhazip.com').read().decode('utf8').strip('\n'))

# %%
# 5. Run Streamlit App & LocalTunnel!
# Note: This cell will run continuously.
# !streamlit run app_enhanced_fixed.py &>/content/logs.txt &
# !npx localtunnel --port 8501
